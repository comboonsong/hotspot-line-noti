# %%
# in this example let's look at VIIRS NOAA-20, entire world and the most recent day
MAP_KEY = '369c072d72f9f4b7eebc861b88b245f9'
THA_BBOX = '97.229004,5.484768,105.732422,20.612220' # west, south, east, north
SRC_NAME = ["VIIRS_SNPP_NRT", "VIIRS_NOAA20_NRT", "VIIRS_NOAA21_NRT"]

# now remember, after 10 minutes this will reset
src = SRC_NAME[1]
area_url = 'https://firms.modaps.eosdis.nasa.gov/api/area/csv/' + MAP_KEY + '/' + src + '/' + THA_BBOX + '/1'
df_area = pd.read_csv(area_url)

df_area
# Out:
# Empty DataFrame
# Columns: [Invalid area. Expects: [west, south, east, north].]
# Index: []
